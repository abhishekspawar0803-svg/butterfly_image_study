# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("phucthaiv02/butterfly-image-classification")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\Abhishek\.cache\kagglehub\datasets\phucthaiv02\butterfly-image-classification\versions\3

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.image import imread
import tensorflow as tf
# Out:
# C:\Users\Abhishek\tf-env\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
train_path = "C:\\Users\\Abhishek\\.cache\\kagglehub\\datasets\\phucthaiv02\\butterfly-image-classification\\versions\\3\\train\\"
test_path = "C:\\Users\\Abhishek\\.cache\\kagglehub\\datasets\\phucthaiv02\\butterfly-image-classification\\versions\\3\\test\\"

# %%
train_df = pd.read_csv('Training_set.csv')
test_df = pd.read_csv('Testing_set.csv')

# %%
train_df
# Out:
#             filename                     label
# 0        Image_1.jpg          SOUTHERN DOGFACE
# 1        Image_2.jpg                    ADONIS
# 2        Image_3.jpg            BROWN SIPROETA
# 3        Image_4.jpg                   MONARCH
# 4        Image_5.jpg  GREEN CELLED CATTLEHEART
# ...              ...                       ...
# 6494  Image_6495.jpg          MANGROVE SKIPPER
# 6495  Image_6496.jpg            MOURNING CLOAK
# 6496  Image_6497.jpg                   APPOLLO
# 6497  Image_6498.jpg           ELBOWED PIERROT
# 6498  Image_6499.jpg                     ATALA
#
# [6499 rows x 2 columns]

# %%
plt.figure(figsize=(12,12))
sns.countplot(data=train_df, y='label', hue = 'label')
# Out:
# <Axes: xlabel='count', ylabel='label'>

# %%
test_df #no labels, kindoff useless
# Out:
#             filename
# 0        Image_1.jpg
# 1        Image_2.jpg
# 2        Image_3.jpg
# 3        Image_4.jpg
# 4        Image_5.jpg
# ...              ...
# 2781  Image_2782.jpg
# 2782  Image_2783.jpg
# 2783  Image_2784.jpg
# 2784  Image_2785.jpg
# 2785  Image_2786.jpg
#
# [2786 rows x 1 columns]

# %%
import os

# %%
os.listdir(train_path)[0]
# Out:
# 'Image_1.jpg'

# %%
len(os.listdir(train_path))
# Out:
# 6499

# %%
img = imread(train_path+'Image_632.jpg')

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (224, 224, 3)

# %%
# this shape is consistent for all images in this dataset

# %%
#have to associate the df to the image

# %%
224*224
# Out:
# 50176

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
datagen = ImageDataGenerator( rotation_range=1, width_shift_range=0.3, height_shift_range=0.3, validation_split=0.2, rescale=1./255)

# %%
train_datagen = datagen.flow_from_dataframe(train_df, directory=train_path, y_col='label',target_size=(224,224), subset = 'training',save_format='jpg')
# Out:
# Found 5200 validated image filenames belonging to 75 classes.

# %%
val_datagen = datagen.flow_from_dataframe(train_df, directory=train_path, y_col='label',target_size=(224,224), subset = 'validation',save_format='jpg')
# Out:
# Found 1299 validated image filenames belonging to 75 classes.

# %%
label_class =[(v,k) for k,v in train_datagen.class_indices.items()]
label_class
# Out:
# [(0, 'ADONIS'),
#  (1, 'AFRICAN GIANT SWALLOWTAIL'),
#  (2, 'AMERICAN SNOOT'),
#  (3, 'AN 88'),
#  (4, 'APPOLLO'),
#  (5, 'ATALA'),
#  (6, 'BANDED ORANGE HELICONIAN'),
#  (7, 'BANDED PEACOCK'),
#  (8, 'BECKERS WHITE'),
#  (9, 'BLACK HAIRSTREAK'),
#  (10, 'BLUE MORPHO'),
#  (11, 'BLUE SPOTTED CROW'),
#  (12, 'BROWN SIPROETA'),
#  (13, 'CABBAGE WHITE'),
#  (14, 'CAIRNS BIRDWING'),
#  (15, 'CHECQUERED SKIPPER'),
#  (16, 'CHESTNUT'),
#  (17, 'CLEOPATRA'),
#  (18, 'CLODIUS PARNASSIAN'),
#  (19, 'CLOUDED SULPHUR'),
#  (20, 'COMMON BANDED AWL'),
#  (21, 'COMMON WOOD-NYMPH'),
#  (22, 'COPPER TAIL'),
#  (23, 'CRECENT'),
#  (24, 'CRIMSON PATCH'),
#  (25, 'DANAID EGGFLY'),
#  (26, 'EASTERN COMA'),
#  (27, 'EASTERN DAPPLE WHITE'),
#  (28, 'EASTERN PINE ELFIN'),
#  (29, 'ELBOWED PIERROT'),
#  (30, 'GOLD BANDED'),
#  (31, 'GREAT EGGFLY'),
#  (32, 'GREAT JAY'),
#  (33, 'GREEN CELLED CATTLEHEART'),
#  (34, 'GREY HAIRSTREAK'),
#  (35, 'INDRA SWALLOW'),
#  (36, 'IPHICLUS SISTER'),
#  (37, 'JULIA'),
#  (38, 'LARGE MARBLE'),
#  (39, 'MALACHITE'),
#  (40, 'MANGROVE SKIPPER'),
#  (41, 'MESTRA'),
#  (42, 'METALMARK'),
#  (43, 'MILBERTS TORTOISESHELL'),
#  (44, 'MONARCH'),
#  (45, 'MOURNING CLOAK'),
#  (46, 'ORANGE OAKLEAF'),
#  (47, 'ORANGE TIP'),
#  (48, 'ORCHARD SWALLOW'),
#  (49, 'PAINTED LADY'),
#  (50, 'PAPER KITE'),
#  (51, 'PEACOCK'),
#  (52, 'PINE WHITE'),
#  (53, 'PIPEVINE SWALLOW'),
#  (54, 'POPINJAY'),
#  (55, 'PURPLE HAIRSTREAK'),
#  (56, 'PURPLISH COPPER'),
#  (57, 'QUESTION MARK'),
#  (58, 'RED ADMIRAL'),
#  (59, 'RED CRACKER'),
#  (60, 'RED POSTMAN'),
#  (61, 'RED SPOTTED PURPLE'),
#  (62, 'SCARCE SWALLOW'),
#  (63, 'SILVER SPOT SKIPPER'),
#  (64, 'SLEEPY ORANGE'),
#  (65, 'SOOTYWING'),
#  (66, 'SOUTHERN DOGFACE'),
#  (67, 'STRAITED QUEEN'),
#  (68, 'TROPICAL LEAFWING'),
#  (69, 'TWO BARRED FLASHER'),
#  (70, 'ULYSES'),
#  (71, 'VICEROY'),
#  (72, 'WOOD SATYR'),
#  (73, 'YELLOW SWALLOW TAIL'),
#  (74, 'ZEBRA LONG WING')]

# %%
random = np.random.randint(5200)

path = train_datagen.filepaths[random]
plt.imshow(imread(path))
label = train_datagen.classes[random]
print(f'This one is called : \n {label_class[label][1]}\n')
# Out:
# This one is called :
#  COMMON BANDED AWL

# %%
plt.imshow(datagen.random_transform(imread(path)))

# %%
#model now

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Input, MaxPool2D, GlobalAveragePooling2D, BatchNormalization, Activation, Dropout, Flatten

# %%
224*224
# Out:
# 50176

# %%
image_classifier = Sequential()

image_classifier.add(Input(shape=[224,224,3]))
image_classifier.add(Conv2D(filters=32, kernel_size=(3,3), padding='same'))
image_classifier.add(BatchNormalization())
image_classifier.add(Activation('relu'))
image_classifier.add(MaxPool2D(pool_size=(2,2)))

image_classifier.add(Conv2D(filters=64, kernel_size=(3,3), padding='same'))
image_classifier.add(BatchNormalization())
image_classifier.add(Activation('relu'))
image_classifier.add(MaxPool2D(pool_size=(2,2)))

image_classifier.add(Conv2D(filters=128, kernel_size=(3,3), padding='same'))
image_classifier.add(BatchNormalization())
image_classifier.add(Activation('relu'))
image_classifier.add(MaxPool2D(pool_size=(2,2)))

image_classifier.add(Conv2D(filters=256, kernel_size=(3,3), padding='same'))
image_classifier.add(BatchNormalization())
image_classifier.add(Activation('relu'))
image_classifier.add(MaxPool2D(pool_size=(2,2)))

image_classifier.add(GlobalAveragePooling2D())
image_classifier.add(Dropout(0.25))
image_classifier.add(Dense(256, activation='relu'))
image_classifier.add(Dropout(0.25))
image_classifier.add(Dense(128, activation='relu'))
image_classifier.add(Dense(75, activation='softmax'))


image_classifier.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
image_classifier.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 224, 224, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 224, 224, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 224, 224, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 112, 112, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 112, 112, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 112, 112, 64)        │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 56, 56, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 56, 56, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 56, 56, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_2 (Activation)            │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 28, 28, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 28, 28, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 28, 28, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_3 (Activation)            │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 14, 14, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 256)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │          65,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 75)                  │           9,675 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 498,699 (1.90 MB)
#  Trainable params: 497,739 (1.90 MB)
#  Non-trainable params: 960 (3.75 KB)

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop=EarlyStopping(mode='min', patience = 15, restore_best_weights=True)

# %%
image_classifier.fit(train_datagen, validation_data=val_datagen, epochs=2000, callbacks=[early_stop])
# Out:
# Epoch 1/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 128s 766ms/step - accuracy: 0.0717 - loss: 3.9195 - val_accuracy: 0.0146 - val_loss: 4.9157
# Epoch 2/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 120s 736ms/step - accuracy: 0.1431 - loss: 3.3254 - val_accuracy: 0.0185 - val_loss: 4.8438
# Epoch 3/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 118s 724ms/step - accuracy: 0.2013 - loss: 2.9764 - val_accuracy: 0.0893 - val_loss: 3.9855
# Epoch 4/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 122s 746ms/step - accuracy: 0.2567 - loss: 2.7514 - val_accuracy: 0.2540 - val_loss: 2.7795
# Epoch 5/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 120s 733ms/step - accuracy: 0.2896 - loss: 2.5468 - val_accuracy: 0.2741 - val_loss: 2.6214
# Epoch 6/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 120s 736ms/step - accuracy: 0.3188 - loss: 2.3926 - val_accuracy: 0.2079 - val_loss: 3.4283
# Epoch 7/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 119s 728ms/step - accuracy: 0.3712 - loss: 2.2525 - val_accuracy: 0.2625 - val_loss: 3.2211
# Epoch 8/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 118s 724ms/step - accuracy: 0.3806 - loss: 2.1776 - val_accuracy: 0.2841 - val_loss: 2.8297
# Epoch 9/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 120s 735ms/step - accuracy: 0.4085 - loss: 2.0607 - val_accuracy: 0.3195 - val_loss: 2.5360
# Epoch 10/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 122s 750ms/step - accuracy: 0.4244 - loss: 1.9865 - val_accuracy: 0.3788 - val_loss: 2.2339
# Epoch 11/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 128s 781ms/step - accuracy: 0.4408 - loss: 1.9306 - val_accuracy: 0.2818 - val_loss: 2.8071
# Epoch 12/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 122s 744ms/step - accuracy: 0.4644 - loss: 1.8396 - val_accuracy: 0.2186 - val_loss: 3.5518
# Epoch 13/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 119s
2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 117s 714ms/step - accuracy: 0.8767 - loss: 0.3694 - val_accuracy: 0.7537 - val_loss: 0.9797
# Epoch 87/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 117s 715ms/step - accuracy: 0.8723 - loss: 0.3863 - val_accuracy: 0.7229 - val_loss: 1.1463
# Epoch 88/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 116s 713ms/step - accuracy: 0.8715 - loss: 0.3887 - val_accuracy: 0.7644 - val_loss: 0.9150
# Epoch 89/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 116s 713ms/step - accuracy: 0.8712 - loss: 0.3901 - val_accuracy: 0.7683 - val_loss: 0.9605
# Epoch 90/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 116s 713ms/step - accuracy: 0.8673 - loss: 0.3842 - val_accuracy: 0.7983 - val_loss: 0.7880
# Epoch 91/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 118s 726ms/step - accuracy: 0.8673 - loss: 0.4041 - val_accuracy: 0.7513 - val_loss: 0.9115
# Epoch 92/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 121s 744ms/step - accuracy: 0.8819 - loss: 0.3525 - val_accuracy: 0.7714 - val_loss: 0.9304
# Epoch 93/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 122s 750ms/step - accuracy: 0.8837 - loss: 0.3601 - val_accuracy: 0.6898 - val_loss: 1.3512
# Epoch 94/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 127s 778ms/step - accuracy: 0.8758 - loss: 0.3756 - val_accuracy: 0.7629 - val_loss: 0.9160
# Epoch 95/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 123s 756ms/step - accuracy: 0.8698 - loss: 0.3890 - val_accuracy: 0.7791 - val_loss: 0.8361
# Epoch 96/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 123s 752ms/step - accuracy: 0.8838 - loss: 0.3609 - val_accuracy: 0.7552 - val_loss: 0.9135
# Epoch 97/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 123s 752ms/step - accuracy: 0.8838 - loss: 0.3571 - val_accuracy: 0.7436 - val_loss: 1.0166
# Epoch 98/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 123s 750ms/step - accuracy: 0.8846 - loss: 0.3429 - val_accuracy: 0.7221 - val_loss: 1.0898
# Epoch 99/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 122s 750ms/step - accuracy: 0.8867 - loss: 0.3341 - val_accuracy: 0.7714 - val_loss: 0.9741
# Epoch 100/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 122s 748ms/step - accuracy: 0.8846 - loss: 0.3484 - val_accuracy: 0.7821 - val_loss: 0.8993
# Epoch 101/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 122s 748ms/step - accuracy: 0.8858 - loss: 0.3345 - val_accuracy: 0.6967 - val_loss: 1.3067
# Epoch 102/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 122s 748ms/step - accuracy: 0.8865 - loss: 0.3312 - val_accuracy: 0.7768 - val_loss: 0.9006
# Epoch 103/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 122s 748ms/step - accuracy: 0.8865 - loss: 0.3357 - val_accuracy: 0.7737 - val_loss: 0.9021
# Epoch 104/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 122s 749ms/step - accuracy: 0.8935 - loss: 0.3296 - val_accuracy: 0.7113 - val_loss: 1.1622
# Epoch 105/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 117s 715ms/step - accuracy: 0.8927 - loss: 0.3357 - val_accuracy: 0.7721 - val_loss: 0.8548

# %%
metrics = pd.DataFrame(image_classifier.history.history)

# %%
metrics[['accuracy', 'val_accuracy']].plot()
# Out:
# <Axes: >

# %%
metrics[['loss', 'val_loss']].plot()
# Out:
# <Axes: >

# %%
image_classifier.evaluate(val_datagen)
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 12s 287ms/step - accuracy: 0.7898 - loss: 0.7961
# [0.7961475849151611, 0.7898383140563965]

# %%
x_list=[]
y_list = []
for i in range(len(val_datagen)):    
    xbatch, ybatch = next(val_datagen)
    y_list.append(ybatch)
    x_list.append(xbatch)

# %%
xseq = np.concatenate(x_list, axis=0)

# %%
xseq.shape
# Out:
# (1299, 224, 224, 3)

# %%
pred = image_classifier.predict(xseq)
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s
#     accuracy                           0.79      1299
#    macro avg       0.80      0.79      0.79      1299
# weighted avg       0.81      0.79      0.79      1299

# %%
# beginning transfer learning

# %%
train_datagen.batch_size
# Out:
# 32

# %%
val_datagen.image_shape
# Out:
# (224, 224, 3)

# %%
from tensorflow.keras.applications import EfficientNetV2B0

# %%
transfer = EfficientNetV2B0(include_top=False, weights= 'imagenet' , input_shape=[224,224,3], include_preprocessing=False)

# %%
transfer.trainable = False

# %%
# using functional api, instead of sequential

# %%
x = transfer.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.25)(x)
x = Dense(128, activation='relu')(x)
output= Dense(75, activation='softmax')(x)

# %%
from tensorflow.keras import Model

# %%
transfer_model = Model(inputs=transfer.input, outputs = output )

# %%
transfer_model.summary()
# Out:
# Model: "functional_22"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)    │ (None, 224, 224, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ stem_conv (Conv2D)            │ (None, 112, 112, 32)      │             864 │ input_layer_1[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ stem_bn (BatchNormalization)  │ (None, 112, 112, 32)      │             128 │ stem_conv[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ stem_activation (Activation)  │ (None, 112, 112, 32)      │               0 │ stem_bn[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block1a_project_conv (Conv2D) │ (None, 112, 112, 16)      │           4,608 │ stem_activation[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block1a_project_bn            │ (None, 112, 112, 16)      │              64 │ block1a_project_conv[0][0] │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block1a_project_activation    │ (None, 112, 112, 16)      │               0 │ block1a_project_bn[0][0]   │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2a_expand_conv (Conv2D)  │ (None, 56, 56, 64)        │           9,216 │ block1a_project_activatio… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2a_expand_bn             │ (None, 56, 56, 64)        │             256 │ block2a_expand_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2a_expand_activation     │ (None, 56, 56, 64)        │               0 │ block2a_expand_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2a_project_conv (Conv2D) │ (None, 56, 56, 32)        │           2,048 │ block2a_expand_activation… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2a_project_bn            │ (None, 56, 56, 32)        │             128 │ block2a_project_conv[0][0] │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2b_expand_conv (Conv2D)  │ (None, 56, 56, 128)       │          36,864 │ block2a_project_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2b_expand_bn             │ (None, 56, 56, 128)       │             512 │ block2b_expand_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2b_expand_activation     │ (None, 56, 56, 128)       │               0 │ block2b_expand_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2b_project_conv (Conv2D) │ (None, 56, 56, 32)        │           4,096 │ block2b_expand_activation… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2b_project_bn            │ (None, 56, 56, 32)        │             128 │ block2b_project_conv[0][0] │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2b_drop (Dropout)        │ (None, 56, 56, 32)        │               0 │ block2b_project_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2b_add (Add)             │ (None, 56, 56, 32)        │               0 │ block2b_drop[0][0],        │
# │                               │                           │                 │ block2a_project_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3a_expand_conv (Conv2D)  │ (None, 28, 28, 128)       │          36,864 │ block2b_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3a_expand_bn             │ (None, 28, 28, 128)       │             512 │ block3a_expand_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3a_expand_activation     │ (None, 28, 28, 128)       │               0 │ block3a_expand_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3a_project_conv (Conv2D) │ (None, 28, 28, 48)        │           6,144 │ block3a_expand_activation… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3a_project_bn            │ (None, 28, 28, 48)        │             192 │ block3a_project_conv[0][0] │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3b_expand_conv (Conv2D)  │ (None, 28, 28, 192)       │          82,944 │ block3a_project_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3b_expand_bn             │ (None, 28, 28, 192)       │             768 │ block3b_expand_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3b_expand_activation     │ (None, 28, 28, 192)       │               0 │ block3b_expand_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3b_project_conv (Conv2D) │ (None, 28, 28, 48)        │           9,216 │ block3b_expand_activation… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3b_project_bn            │ (None, 28, 28, 48)        │             192 │ block3b_project_conv[0][0] │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3b_drop (Dropout)        │ (None, 28, 28, 48)        │               0 │ block3b_project_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3b_add (Add)             │ (None, 28, 28, 48)        │               0 │ block3b_drop[0][0],        │
# │                               │                           │                 │ block3a_project_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4a_expand_conv (Conv2D)  │ (None, 28, 28, 192)       │           9,216 │ block3b_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4a_expand_bn             │ (None, 28, 28, 192)       │             768 │ block4a_expand_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4a_expand_activation     │ (None, 28, 28, 192)       │               0 │ block4a_expand_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4a_dwconv2               │ (None, 14, 14, 192)       │           1,728 │ block4a_expand_activation… │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4a_bn                    │ (None, 14, 14, 192)       │             768 │ block4a_dwconv2[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4a_activation            │ (None, 14, 14, 192)       │               0 │ block4a_bn[0][0]           │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4a_se_squeeze            │ (None, 192)               │               0 │ block4a_activation[0][0]   │
# │ (GlobalAveragePooling2D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4a_se_reshape (Reshape)  │ (None, 1, 1, 192)         │               0 │ block4a_se_squeeze[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4a_se_reduce (Conv2D)    │ (None, 1, 1, 12)          │           2,316 │ block4a_se_reshape[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4a_se_expand (Conv2D)    │ (None, 1, 1, 192)         │           2,496 │ block4a_se_reduce[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4a_se_excite (Multiply)  │ (None, 14, 14, 192)       │               0 │ block4a_activation[0][0],  │
# │                               │                           │                 │ block4a_se_expand[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4a_project_conv (Conv2D) │ (None, 14, 14, 96)        │          18,432 │ block4a_se_excite[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4a_project_bn            │ (None, 14, 14, 96)        │             384 │ block4a_project_conv[0][0] │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4b_expand_conv (Conv2D)  │ (None, 14, 14, 384)       │          36,864 │ block4a_project_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4b_expand_bn             │ (None, 14, 14, 384)       │           1,536 │ block4b_expand_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4b_expand_activation     │ (None, 14, 14, 384)       │               0 │ block4b_expand_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4b_dwconv2               │ (None, 14, 14, 384)       │           3,456 │ block4b_expand_activation… │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4b_bn                    │ (None, 14, 14, 384)       │           1,536 │ block4b_dwconv2[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4b_activation            │ (None, 14, 14, 384)       │               0 │ block4b_bn[0][0]           │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4b_se_squeeze            │ (None, 384)               │               0 │ block4b_activation[0][0]   │
# │ (GlobalAveragePooling2D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4b_se_reshape (Reshape)  │ (None, 1, 1, 384)         │               0 │ block4b_se_squeeze[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4b_se_reduce (Conv2D)    │ (None, 1, 1, 24)          │           9,240 │ block4b_se_reshape[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4b_se_expand (Conv2D)    │ (None, 1, 1, 384)         │           9,600 │ block4b_se_reduce[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4b_se_excite (Multiply)  │ (None, 14, 14, 384)       │               0 │ block4b_activation[0][0],  │
# │                               │                           │                 │ block4b_se_expand[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4b_project_conv (Conv2D) │ (None, 14, 14, 96)        │          36,864 │ block4b_se_excite[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4b_project_bn            │ (None, 14, 14, 96)        │             384 │ block4b_project_conv[0][0] │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4b_drop (Dropout)        │ (None, 14, 14, 96)        │               0 │ block4b_project_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4b_add (Add)             │ (None, 14, 14, 96)        │               0 │ block4b_drop[0][0],        │
# │                               │                           │                 │ block4a_project_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4c_expand_conv (Conv2D)  │ (None, 14, 14, 384)       │          36,864 │ block4b_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4c_expand_bn             │ (None, 14, 14, 384)       │           1,536 │ block4c_expand_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4c_expand_activation     │ (None, 14, 14, 384)       │               0 │ block4c_expand_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4c_dwconv2               │ (None, 14, 14, 384)       │           3,456 │ block4c_expand_activation… │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4c_bn                    │ (None, 14, 14, 384)       │           1,536 │ block4c_dwconv2[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4c_activation            │ (None, 14, 14, 384)       │               0 │ block4c_bn[0][0]           │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4c
project_conv[0][0] │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5b_drop (Dropout)        │ (None, 14, 14, 112)       │               0 │ block5b_project_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5b_add (Add)             │ (None, 14, 14, 112)       │               0 │ block5b_drop[0][0],        │
# │                               │                           │                 │ block5a_project_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5c_expand_conv (Conv2D)  │ (None, 14, 14, 672)       │          75,264 │ block5b_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5c_expand_bn             │ (None, 14, 14, 672)       │           2,688 │ block5c_expand_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5c_expand_activation     │ (None, 14, 14, 672)       │               0 │ block5c_expand_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5c_dwconv2               │ (None, 14, 14, 672)       │           6,048 │ block5c_expand_activation… │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5c_bn                    │ (None, 14, 14, 672)       │           2,688 │ block5c_dwconv2[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5c_activation            │ (None, 14, 14, 672)       │               0 │ block5c_bn[0][0]           │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5c_se_squeeze            │ (None, 672)               │               0 │ block5c_activation[0][0]   │
# │ (GlobalAveragePooling2D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5c_se_reshape (Reshape)  │ (None, 1, 1, 672)         │               0 │ block5c_se_squeeze[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5c_se_reduce (Conv2D)    │ (None, 1, 1, 28)          │          18,844 │ block5c_se_reshape[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5c_se_expand (Conv2D)    │ (None, 1, 1, 672)         │          19,488 │ block5c_se_reduce[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5c_se_excite (Multiply)  │ (None, 14, 14, 672)       │               0 │ block5c_activation[0][0],  │
# │                               │                           │                 │ block5c_se_expand[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5c_project_conv (Conv2D) │ (None, 14, 14, 112)       │          75,264 │ block5c_se_excite[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5c_project_bn            │ (None, 14, 14, 112)       │             448 │ block5c_project_conv[0][0] │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5c_drop (Dropout)        │ (None, 14, 14, 112)       │               0 │ block5c_project_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5c_add (Add)             │ (None, 14, 14, 112)       │               0 │ block5c_drop[0][0],        │
# │                               │                           │                 │ block5b_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5d_expand_conv (Conv2D)  │ (None, 14, 14, 672)       │          75,264 │ block5c_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5d_expand_bn             │ (None, 14, 14, 672)       │           2,688 │ block5d_expand_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5d_expand_activation     │ (None, 14, 14, 672)       │               0 │ block5d_expand_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5d_dwconv2               │ (None, 14, 14, 672)       │           6,048 │ block5d_expand_activation… │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5d_bn                    │ (None, 14, 14, 672)       │           2,688 │ block5d_dwconv2[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5d_activation            │ (None, 14, 14, 672)       │               0 │ block5d_bn[0][0]           │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5d_se_squeeze            │ (None, 672)               │               0 │ block5d_activation[0][0]   │
# │ (GlobalAveragePooling2D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5d_se_reshape (Reshape)  │ (None, 1, 1, 672)         │               0 │ block5d_se_squeeze[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5d_se_reduce (Conv2D)    │ (None, 1, 1, 28)          │          18,844 │ block5d_se_reshape[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5d_se_expand (Conv2D)    │ (None, 1, 1, 672)         │          19,488 │ block5d_se_reduce[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5d_se_excite (Multiply)  │ (None, 14, 14, 672)       │               0 │ block5d_activation[0][0],  │
# │                               │                           │                 │ block5d_se_expand[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5d_project_conv (Conv2D) │ (None, 14, 14, 112)       │          75,264 │ block5d_se_excite[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5d_project_bn            │ (None, 14, 14, 112)       │             448 │ block5d_project_conv[0][0] │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5d_drop (Dropout)        │ (None, 14, 14, 112)       │               0 │ block5d_project_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5d_add (Add)             │ (None, 14, 14, 112)       │               0 │ block5d_drop[0][0],        │
# │                               │                           │                 │ block5c_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5e_expand_conv (Conv2D)  │ (None, 14, 14, 672)       │          75,264 │ block5d_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5e_expand_bn             │ (None, 14, 14, 672)       │           2,688 │ block5e_expand_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5e_expand_activation     │ (None, 14, 14, 672)       │               0 │ block5e_expand_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5e_dwconv2               │ (None, 14, 14, 672)       │           6,048 │ block5e_expand_activation… │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5e
project_conv[0][0] │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6e_drop (Dropout)        │ (None, 7, 7, 192)         │               0 │ block6e_project_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6e_add (Add)             │ (None, 7, 7, 192)         │               0 │ block6e_drop[0][0],        │
# │                               │                           │                 │ block6d_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6f_expand_conv (Conv2D)  │ (None, 7, 7, 1152)        │         221,184 │ block6e_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6f_expand_bn             │ (None, 7, 7, 1152)        │           4,608 │ block6f_expand_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6f_expand_activation     │ (None, 7, 7, 1152)        │               0 │ block6f_expand_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6f_dwconv2               │ (None, 7, 7, 1152)        │          10,368 │ block6f_expand_activation… │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6f_bn                    │ (None, 7, 7, 1152)        │           4,608 │ block6f_dwconv2[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6f_activation            │ (None, 7, 7, 1152)        │               0 │ block6f_bn[0][0]           │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6f_se_squeeze            │ (None, 1152)              │               0 │ block6f_activation[0][0]   │
# │ (GlobalAveragePooling2D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6f_se_reshape (Reshape)  │ (None, 1, 1, 1152)        │               0 │ block6f_se_squeeze[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6f_se_reduce (Conv2D)    │ (None, 1, 1, 48)          │          55,344 │ block6f_se_reshape[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6f_se_expand (Conv2D)    │ (None, 1, 1, 1152)        │          56,448 │ block6f_se_reduce[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6f_se_excite (Multiply)  │ (None, 7, 7, 1152)        │               0 │ block6f_activation[0][0],  │
# │                               │                           │                 │ block6f_se_expand[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6f_project_conv (Conv2D) │ (None, 7, 7, 192)         │         221,184 │ block6f_se_excite[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6f_project_bn            │ (None, 7, 7, 192)         │             768 │ block6f_project_conv[0][0] │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6f_drop (Dropout)        │ (None, 7, 7, 192)         │               0 │ block6f_project_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6f_add (Add)             │ (None, 7, 7, 192)         │               0 │ block6f_drop[0][0],        │
# │                               │                           │                 │ block6e_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6g_expand_conv (Conv2D)  │ (None, 7, 7, 1152)        │         221,184 │ block6f_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6g_expand_bn             │ (None, 7, 7, 1152)        │           4,608 │ block6g_expand_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6g_expand_activation     │ (None, 7, 7, 1152)        │               0 │ block6g_expand_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6g_dwconv2               │ (None, 7, 7, 1152)        │          10,368 │ block6g_expand_activation… │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6g_bn                    │ (None, 7, 7, 1152)        │           4,608 │ block6g_dwconv2[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6g_activation            │ (None, 7, 7, 1152)        │               0 │ block6g_bn[0][0]           │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6g_se_squeeze            │ (None, 1152)              │               0 │ block6g_activation[0][0]   │
# │ (GlobalAveragePooling2D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6g_se_reshape (Reshape)  │ (None, 1, 1, 1152)        │               0 │ block6g_se_squeeze[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6g_se_reduce (Conv2D)    │ (None, 1, 1, 48)          │          55,344 │ block6g_se_reshape[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6g_se_expand (Conv2D)    │ (None, 1, 1, 1152)        │          56,448 │ block6g_se_reduce[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6g_se_excite (Multiply)  │ (None, 7, 7, 1152)        │               0 │ block6g_activation[0][0],  │
# │                               │                           │                 │ block6g_se_expand[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6g_project_conv (Conv2D) │ (None, 7, 7, 192)         │         221,184 │ block6g_se_excite[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6g_project_bn            │ (None, 7, 7, 192)         │             768 │ block6g_project_conv[0][0] │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6g_drop (Dropout)        │ (None, 7, 7, 192)         │               0 │ block6g_project_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6g_add (Add)             │ (None, 7, 7, 192)         │               0 │ block6g_drop[0][0],        │
# │                               │                           │                 │ block6f_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6h_expand_conv (Conv2D)  │ (None, 7, 7, 1152)        │         221,184 │ block6g_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6h_expand_bn             │ (None, 7, 7, 1152)        │           4,608 │ block6h_expand_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6h_expand_activation     │ (None, 7, 7, 1152)        │               0 │ block6h_expand_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6h_dwconv2               │ (None, 7, 7, 1152)        │          10,368 │ block6h_expand_activation… │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6h_bn                    │ (None, 7, 7, 1152)        │           4,608 │ block6h_dwconv2[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6h_activation            │ (None, 7, 7, 1152)        │               0 │ block6h_bn[0][0]           │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6h_se_squeeze            │ (None, 1152)              │               0 │ block6h_activation[0][0]   │
# │ (GlobalAveragePooling2D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6h_se_reshape (Reshape)  │ (None, 1, 1, 1152)        │               0 │ block6h_se_squeeze[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6h_se_reduce (Conv2D)    │ (None, 1, 1, 48)          │          55,344 │ block6h_se_reshape[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6h_se_expand (Conv2D)    │ (None, 1, 1, 1152)        │          56,448 │ block6h_se_reduce[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6h_se_excite (Multiply)  │ (None, 7, 7, 1152)        │               0 │ block6h_activation[0][0],  │
# │                               │                           │                 │ block6h_se_expand[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6h_project_conv (Conv2D) │ (None, 7, 7, 192)         │         221,184 │ block6h_se_excite[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6h_project_bn            │ (None, 7, 7, 192)         │             768 │ block6h_project_conv[0][0] │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6h_drop (Dropout)        │ (None, 7, 7, 192)         │               0 │ block6h_project_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6h_add (Add)             │ (None, 7, 7, 192)         │               0 │ block6h_drop[0][0],        │
# │                               │                           │                 │ block6g_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ top_conv (Conv2D)             │ (None, 7, 7, 1280)        │         245,760 │ block6h_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ top_bn (BatchNormalization)   │ (None, 7, 7, 1280)        │           5,120 │ top_conv[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ top_activation (Activation)   │ (None, 7, 7, 1280)        │               0 │ top_bn[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_average_pooling2d_1    │ (None, 1280)              │               0 │ top_activation[0][0]       │
# │ (GlobalAveragePooling2D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_3 (Dense)               │ (None, 256)               │         327,936 │ global_average_pooling2d_… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_2 (Dropout)           │ (None, 256)               │               0 │ dense_3[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_4 (Dense)               │ (None, 128)               │          32,896 │ dropout_2[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_5 (Dense)               │ (None, 75)                │           9,675 │ dense_4[0][0]              │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 6,289,819 (23.99 MB)
#  Trainable params: 370,507 (1.41 MB)
#  Non-trainable params: 5,919,312 (22.58 MB)

# %%
early_stop=EarlyStopping(mode='min', patience = 15, restore_best_weights=True)

# %%
transfer_model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics=['accuracy'])

# %%
transfer_model.fit(train_datagen,validation_data=val_datagen, epochs = 2000, callbacks=[early_stop] )
# Out:
# Epoch 1/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 456ms/step - accuracy: 0.2977 - loss: 2.8983 - val_accuracy: 0.6212 - val_loss: 1.3908
# Epoch 2/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 73s 447ms/step - accuracy: 0.6508 - loss: 1.2178 - val_accuracy: 0.7560 - val_loss: 0.8669
# Epoch 3/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 72s 444ms/step - accuracy: 0.7583 - loss: 0.8261 - val_accuracy: 0.7737 - val_loss: 0.7618
# Epoch 4/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 65s 398ms/step - accuracy: 0.7910 - loss: 0.6987 - val_accuracy: 0.8029 - val_loss: 0.6712
# Epoch 5/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 65s 398ms/step - accuracy: 0.8198 - loss: 0.6067 - val_accuracy: 0.8276 - val_loss: 0.6067
# Epoch 6/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 65s 399ms/step - accuracy: 0.8335 - loss: 0.5325 - val_accuracy: 0.8337 - val_loss: 0.5473
# Epoch 7/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 65s 398ms/step - accuracy: 0.8508 - loss: 0.4746 - val_accuracy: 0.8422 - val_loss: 0.5524
# Epoch 8/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 65s 398ms/step - accuracy: 0.8648 - loss: 0.4311 - val_accuracy: 0.8399 - val_loss: 0.5422
# Epoch 9/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 65s 399ms/step - accuracy: 0.8735 - loss: 0.4048 - val_accuracy: 0.8345 - val_loss: 0.5914
# Epoch 10/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 65s 397ms/step - accuracy: 0.8798 - loss: 0.3900 - val_accuracy: 0.8283 - val_loss: 0.6055
# Epoch 11/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 65s 398ms/step - accuracy: 0.8927 - loss: 0.3435 - val_accuracy: 0.8584 - val_loss: 0.5213
# Epoch 12/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 65s 400ms/step - accuracy: 0.8937 - loss: 0.3342 - val_accuracy: 0.8553 - val_loss: 0.5139
# Epoch 13/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 65s 398ms/step - accuracy: 0.8983 - loss: 0.3243 - val_accuracy: 0.8584 - val_loss: 0.4852
# Epoch 14/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 65s 401ms/step - accuracy: 0.8994 - loss: 0.3089 - val_accuracy: 0.8483 - val_loss: 0.5484
# Epoch 15/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 65s 400ms/step - accuracy: 0.9087 - loss: 0.2840 - val_accuracy: 0.8560 - val_loss: 0.5464
# Epoch 16/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 65s 398ms/step - accuracy: 0.9004 - loss: 0.3067 - val_accuracy: 0.8530 - val_loss: 0.5186
# Epoch 17/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 65s 399ms/step - accuracy: 0.9071 - loss: 0.2825 - val_accuracy: 0.8622 - val_loss: 0.5175
# Epoch 18/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 65s 399ms/step - accuracy: 0.9029 - loss: 0.2878 - val_accuracy: 0.8507 - val_loss: 0.5655
# Epoch 19/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 65s 399ms/step - accuracy: 0.9146 - loss: 0.2635 - val_accuracy: 0.8699 - val_loss: 0.4881
# Epoch 20/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 65s 398ms/step - accuracy: 0.9212 - loss: 0.2378 - val_accuracy: 0.8637 - val_loss: 0.5247
# Epoch 21/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 65s 398ms/step - accuracy: 0.9217 - loss: 0.2313 - val_accuracy: 0.8591 - val_loss: 0.5279
# Epoch 22/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 65s 398ms/step - accuracy: 0.9188 - loss: 0.2378 - val_accuracy: 0.8645 - val_loss: 0.5316
# Epoch 23/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 65s 398ms/step - accuracy: 0.9231 - loss: 0.2358 - val_accuracy: 0.8537 - val_loss: 0.5654
# Epoch 24/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 65s 398ms/step - accuracy: 0.9262 - loss: 0.2101 - val_accuracy: 0.8691 - val_loss: 0.5664
# Epoch 25/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 65s 399ms/step - accuracy: 0.9283 - loss: 0.2047 - val_accuracy: 0.8607 - val_loss: 0.5730
# Epoch 26/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 66s 404ms/step - accuracy: 0.9308 - loss: 0.2084 - val_accuracy: 0.8537 - val_loss: 0.5414
# Epoch 27/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 65s 398ms/step - accuracy: 0.9256 - loss: 0.2190 - val_accuracy: 0.8630 - val_loss: 0.5448
# Epoch 28/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 65s 398ms/step - accuracy: 0.9313 - loss: 0.2106 - val_accuracy: 0.8514 - val_loss: 0.6038

# %%
metrics = pd.DataFrame(transfer_model.history.history)

# %%
metrics[['accuracy', 'val_accuracy']].plot()
# Out:
# <Axes: >

# %%
metrics[['loss', 'val_loss']].plot()
# Out:
# <Axes: >

# %%
transfer_model.evaluate(val_datagen)
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 13s 313ms/step - accuracy: 0.8599 - loss: 0.4974
# [0.49736547470092773, 0.8598922491073608]

# %%
x_list=[]
y_list = []
for i in range(len(val_datagen)):    
    xbatch, ybatch = next(val_datagen)
    y_list.append(ybatch)
    x_list.append(xbatch)

# %%
xseq = np.concatenate(x_list, axis=0)
yseq = np.concatenate(y_list, axis=0)

# %%
pred = transfer_model.predict(xseq)
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 209ms/step

# %%
pred = np.argmax(pred, axis=-1)
y_true = np.argmax(yseq, axis=-1)

# %%
pred
# Out:
# array([50, 72, 36, ..., 53, 36, 20], shape=(1299,))

# %%
y_true
# Out:
# array([50, 72, 36, ..., 53, 36, 20], shape=(1299,))

# %%
sns.heatmap(confusion_matrix(y_true, pred))
# Out:
# <Axes: >

# %%
print(classification_report(y_true, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.89      0
auto_val_datagen = datagen.flow_from_dataframe(train_df, directory=train_path, y_col=None,target_size=(224,224), subset = 'validation',save_format='jpg', class_mode='input')
# Out:
# Found 1299 validated image filenames.

# %%
from tensorflow.keras.layers import Reshape, Conv2DTranspose

# %%
encoder = Sequential()
encoder.add(Input([224,224,3]))
encoder.add(Conv2D(32,3,padding='same', activation='relu'))
encoder.add(MaxPool2D())
encoder.add(Conv2D(64,3,padding='same', activation='relu'))
encoder.add(MaxPool2D())
encoder.add(Conv2D(128,3,padding='same', activation='relu'))
encoder.add(MaxPool2D())
encoder.add(Conv2D(256,3,padding='same', activation='relu'))
encoder.add(MaxPool2D())

# %%
decoder = Sequential()
decoder.add(Input([14,14,256]))
decoder.add(Conv2DTranspose(128,3,strides=2, padding='same', activation='relu'))
decoder.add(Conv2DTranspose(64,3,strides=2, padding='same', activation='relu'))
decoder.add(Conv2DTranspose(32,3,strides=2, padding='same', activation='relu'))
decoder.add(Conv2DTranspose(3,3,strides=2, padding='same', activation='sigmoid'))

# %%
decoder.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_transpose (Conv2DTranspose)   │ (None, 28, 28, 128)         │         295,040 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose_1 (Conv2DTranspose) │ (None, 56, 56, 64)          │          73,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose_2 (Conv2DTranspose) │ (None, 112, 112, 32)        │          18,464 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose_3 (Conv2DTranspose) │ (None, 224, 224, 3)         │             867 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 388,163 (1.48 MB)
#  Trainable params: 388,163 (1.48 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
autoencoder = Sequential([encoder, decoder])

# %%
autoencoder.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ sequential_1 (Sequential)            │ (None, 14, 14, 256)         │         388,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ sequential_2 (Sequential)            │ (None, 224, 224, 3)         │         388,163 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 776,579 (2.96 MB)
#  Trainable params: 776,579 (2.96 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
autoencoder.compile(optimizer='adam',loss='mse')

# %%
autoencoder.fit(auto_train_datagen, validation_data=auto_val_datagen, epochs=2000, callbacks=[early_stop], batch_size=8)
# Out:
# Epoch 1/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 84s 506ms/step - loss: 0.0367 - val_loss: 0.0148
# Epoch 2/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 502ms/step - loss: 0.0124 - val_loss: 0.0111
# Epoch 3/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 502ms/step - loss: 0.0099 - val_loss: 0.0083
# Epoch 4/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 505ms/step - loss: 0.0078 - val_loss: 0.0074
# Epoch 5/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 501ms/step - loss: 0.0070 - val_loss: 0.0066
# Epoch 6/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 501ms/step - loss: 0.0066 - val_loss: 0.0062
# Epoch 7/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 502ms/step - loss: 0.0060 - val_loss: 0.0061
# Epoch 8/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0057 - val_loss: 0.0055
# Epoch 9/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 502ms/step - loss: 0.0055 - val_loss: 0.0058
# Epoch 10/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 504ms/step - loss: 0.0052 - val_loss: 0.0052
# Epoch 11/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 502ms/step - loss: 0.0051 - val_loss: 0.0054
# Epoch 12/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 502ms/step - loss: 0.0049 - val_loss: 0.0049
# Epoch 13/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 502ms/step - loss: 0.0048 - val_loss: 0.0047
# Epoch 14/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0048 - val_loss: 0.0047
# Epoch 15/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 502ms/step - loss: 0.0046 - val_loss: 0.0047
# Epoch 16/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 501ms/step - loss: 0.0045 - val_loss: 0.0044
# Epoch 17/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0044 - val_loss: 0.0044
# Epoch 18/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 19/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0043 - val_loss: 0.0042
# Epoch 20/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 504ms/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 21/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 501ms/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 22/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 504ms/step - loss: 0.0041 - val_loss: 0.0042
# Epoch 23/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 502ms/step - loss: 0.0041 - val_loss: 0.0042
# Epoch 24/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0040 - val_loss: 0.0039
# Epoch 25/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 26/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0039 - val_loss: 0.0041
# Epoch 27/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 504ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 28/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 502ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 29/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 504ms/step - loss: 0.0038 - val_loss: 0.0037
# Epoch 30/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0037 - val_loss: 0.0039
# Epoch 31/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 502ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 32/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 33/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 34/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 502ms/step - loss: 0.0036 - val_loss: 0.0035
# Epoch 35/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 36/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0035 - val_loss: 0.0055
# Epoch 37/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0038 - val_loss: 0.0035
# Epoch 38/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0035 - val_loss: 0.0034
# Epoch 39/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 502ms/step - loss: 0.0035 - val_loss: 0.0035
# Epoch 40/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0034 - val_loss: 0.0034
# Epoch 41/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0034 - val_loss: 0.0035
# Epoch 42/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 43/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 44/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 504ms/step - loss: 0.0034 - val_loss: 0.0032
# Epoch 45/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0033 - val_loss: 0.0034
# Epoch 46/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 47/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 502ms/step - loss: 0.0033 - val_loss: 0.0038
# Epoch 48/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 505ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 49/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 50/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 502ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 51/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 52/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 53/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 504ms/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 54/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 504ms/step - loss: 0.0031 - val_loss: 0.0033
# Epoch 55/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 502ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 56/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 502ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 57/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 504ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 58/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 502ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 59/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 502ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 60/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 61/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 62/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 504ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 63/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 64/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 502ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 65/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 502ms/step - loss: 0.0030 - val_loss: 0.0035
# Epoch 66/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 67/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 502ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 68/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 69/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 502ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 70/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 504ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 71/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 504ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 72/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 504ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 73/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 502ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 74/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 75/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 76/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 77/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 505ms/step - loss: 0.0036 - val_loss: 0.0060
# Epoch 78/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0034 - val_loss: 0.0029
# Epoch 79/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 502ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 80/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 81/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 505ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 82/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 83/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 84/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 502ms/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 85/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 86/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 504ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 87/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 88/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 504ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 89/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 90/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0027 - val_loss: 0.0030
# Epoch 91/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0028 - val_loss: 0.0032
# Epoch 92/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 502ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 93/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 94/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 502ms/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 95/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 96/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 505ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 97/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 98/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 505ms/step - loss: 0.0027 - val_loss: 0.0029
# Epoch 99/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 504ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 100/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 504ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 101/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 504ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 102/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 103/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 504ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 104/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0026 - val_loss: 0.0027
# Epoch 105/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0026 - val_loss: 0.0028
# Epoch 106/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 504ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 107/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 504ms/step - loss: 0.0026 - val_loss: 0.0027
# Epoch 108/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 504ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 109/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0030 - val_loss: 0.0027
# Epoch 110/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 111/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 112/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 504ms/step - loss: 0.0026 - val_loss: 0.0027
# Epoch 113/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 502ms/step - loss: 0.0026 - val_loss: 0.0028
# Epoch 114/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 505ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 115/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 116/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 504ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 117/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 118/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 119/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 504ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 120/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 121/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 504ms/step - loss: 0.0026 - val_loss: 0.0034
# Epoch 122/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0026 - val_loss: 0.0028
# Epoch 123/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0026 - val_loss: 0.0027
# Epoch 124/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 504ms/step - loss: 0.0025 - val_loss: 0.0027
# Epoch 125/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 505ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 126/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 504ms/step - loss: 0.0026 - val_loss: 0.0027
# Epoch 127/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 84s 514ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 128/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 505ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 129/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 130/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 504ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 131/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 83s 511ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 132/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 90s 553ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 133/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 90s 550ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 134/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 90s 553ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 135/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 91s 555ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 136/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 91s 560ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 137/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 92s 563ms/step - loss: 0.0024 - val_loss: 0.0026
# Epoch 138/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 92s 564ms/step - loss: 0.0026 - val_loss: 0.0024
# Epoch 139/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 92s 561ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 140/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 91s 559ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 141/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 92s 562ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 142/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 88s 540ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 143/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 83s 510ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 144/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 83s 508ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 145/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 83s 510ms/step - loss: 0.0024 - val_loss: 0.0027
# Epoch 146/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 83s 510ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 147/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 86s 528ms/step - loss: 0.0024 - val_loss: 0.0026
# Epoch 148/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 83s 510ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 149/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 84s 512ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 150/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 85s 519ms/step - loss: 0.0025 - val_loss: 0.0027
# Epoch 151/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 83s 510ms/step - loss: 0.0024 - val_loss: 0.0026
# Epoch 152/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 83s 511ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 153/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 83s 511ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 154/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 84s 512ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 155/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 84s 513ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 156/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 84s 514ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 157/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 84s 516ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 158/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 84s 515ms/step - loss: 0.0025 - val_loss: 0.0027
# Epoch 159/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 86s 527ms/step - loss: 0.0024 - val_loss: 0.0028
# Epoch 160/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 84s 517ms/step - loss: 0.0025 - val_loss: 0.0028
# Epoch 161/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 84s 517ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 162/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 85s 519ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 163/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 87s 532ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 164/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 84s 517ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 165/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 84s 518ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 166/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 85s 518ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 167/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 85s 520ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 168/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 84s 517ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 169/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 85s 519ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 170/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 85s 518ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 171/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 84s 517ms/step - loss: 0.0024 - val_loss: 0.0026
# Epoch 172/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 85s 518ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 173/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 85s 519ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 174/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 84s 517ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 175/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 84s 517ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 176/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 85s 518ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 177/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 84s 517ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 178/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 84s 517ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 179/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 84s 518ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 180/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 85s 518ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 181/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 85s 519ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 182/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 84s 517ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 183/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 84s 517ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 184/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 85s 518ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 185/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 85s 519ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 186/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 85s 519ms/step - loss: 0.0027 - val_loss: 0.0024
# Epoch 187/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 84s 517ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 188/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 84s 517ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 189/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 84s 518ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 190/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 84s 517ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 191/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 85s 519ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 192/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 84s 517ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 193/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 84s 517ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 194/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 84s 517ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 195/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 85s 518ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 196/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 85s 518ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 197/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 85s 518ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 198/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 84s 517ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 199/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 85s 519ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 200/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 84s 517ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 201/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 85s 519ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 202/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 84s 518ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 203/2000
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 84s 517ms/step - loss: 0.0023 - val_loss: 0.0024

# %%
#interrupted to check, no valuable gains

# %%
xbatch,_ = next(auto_val_datagen)

# %%
print('original image\n\n')
plt.imshow(xbatch[5])
plt.show()
# Out:
# original image

# %%
len(xbatch)
# Out:
# 32

# %%
pred = autoencoder.predict(xbatch)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step

# %%
n = np.random.randint(0,32)
plt.imshow(xbatch[n])

# %%
plt.imshow(pred[n])

# %%
# turning noise into images, simple gaussian

# %%
z_noise = np.random.normal(size=(20,) + (14,14,256)).astype("float32")

# %%
z_noise[0]
# Out:
# array([[[ 1.02850676e-01,  9.93639290e-01, -2.33359709e-02, ...,
#           3.07355728e-02,  6.40617728e-01,  4.18170393e-02],
#         [ 7.53815532e-01,  1.76323271e+00,  9.07382905e-01, ...,
#           3.13954085e-01,  1.04352486e+00,  8.58070433e-01],
#         [ 5.47251701e-01,  4.70692754e-01, -1.36203992e+00, ...,
#
#        [[ 1.27592731e+00, -2.70316035e-01,  4.92935091e-01, ...,
#          -3.56314272e-01,  9.68275964e-01,  9.77018237e-01],
#         [ 1.32220769e+00,  1.56036261e-02,  1.50651622e+00, ...,
#           6.06565237e-01,  2.12395355e-01, -2.67453283e-01],
#         [ 4.62498605e-01, -1.07871138e-01, -9.63743746e-01, ...,
#          -3.45555842e-01,  7.61728883e-01, -1.51734591e+00],
#         ...,
#         [-1.10914850e+00, -1.83780059e-01,  8.60551417e-01, ...,
#          -9.11173105e-01, -1.43123639e+00, -1.39914185e-01],
#         [ 1.27375022e-01,  2.51924223e-03,  1.08964670e+00, ...,
#           5.94247282e-01,  3.02778572e-01,  6.43464029e-02],
#         [ 1.42809916e+00, -3.54369402e-01, -1.54956400e+00, ...,
#          -1.23177838e+00, -5.15120447e-01,  2.17334509e-01]],
#
#        [[ 2.37621069e-01, -1.38290834e+00, -9.42076206e-01, ...,
#          -8.30223739e-01,  5.13498187e-01, -1.45385969e+00],
#         [ 1.43849742e+00,  2.15977573e+00,  3.84064287e-01, ...,
#           4.87985820e-01, -8.45497668e-01,  3.42975557e-02],
#         [ 4.78090912e-01, -1.64664071e-02,  9.83720541e-01, ...,
#          -1.24528420e+00,  8.14052284e-01,  3.66999283e-02],
#         ...,
#         [-4.33804214e-01,  1.01370525e+00, -1.27550542e+00, ...,
#           7.71696270e-01,  9.34527695e-01,  4.80647564e-01],
#         [-1.35045275e-01, -3.59298140e-02, -1.89338192e-01, ...,
#          -1.07251370e+00,  2.75761902e-01, -1.15396225e+00],
#         [ 2.03052559e-03, -9.50855196e-01, -9.35699105e-01, ...,
#          -8.50000978e-01, -1.39443934e+00, -7.65793562e-01]]],
#       shape=(14, 14, 256), dtype=float32)

# %%
z_pred= decoder.predict(z_noise)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step

# %%
plt.imshow(z_pred[4])

# %%
#thus decoder can only givce this pattern, not a butterfly due to improper latent vectors

# %%
#we require a cvae based model to actually get latent vectors for a proper output

# %%
# this is too complex at this point and thus we skip it

# %%
#only dense based latent vector model we shall try

# %%
encoder.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)                    │ (None, 224, 224, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 112, 112, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 112, 112, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 56, 56, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 56, 56, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 28, 28, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 28, 28, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_7 (MaxPooling2D)       │ (None, 14, 14, 256)         │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 388,416 (1.48 MB)
#  Trainable params: 388,416 (1.48 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
zin = Sequential()
zin.add(Input([256,]))
zin.add(Dense(14*14*256, activation='relu'))
zin.add(Reshape([14,14,256]))

# %%
generator = Sequential([zin, decoder])

# %%
generator.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ sequential_4 (Sequential)            │ (None, 14, 14, 256)         │      12,895,232 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ sequential_2 (Sequential)            │ (None, 224, 224, 3)         │         388,163 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 13,283,395 (50.67 MB)
#  Trainable params: 13,283,395 (50.67 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
noise_decode = np.random.normal(size=(20,) + (14,14,256)).astype("float32")

# %%
pred_decode = decoder.predict(noise_decode)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step

# %%
plt.imshow(pred_decode[0])

# %%
noise_gen = np.random.normal(size=(32,256)).astype("float32")

# %%
pred_gen = generator.predict(noise_gen)
# Out:
# WARNING:tensorflow:5 out of the last 45 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000018221E55620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step

# %%
plt.imshow(pred_gen[10])

# %%
#it does not work as imagined, but thats to be expected
